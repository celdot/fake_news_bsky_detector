# %%
from inference_pipeline import inference
import hopsworks
from flask import jsonify
import os

user_input = "Kylie Jenner & Travis Scott Are Spotted Together Despite Breakup Rumors"
# Retrieve the API key from the environment variable
api_key = os.environ.get("HOPSWORKS_API_KEY")

if not api_key:
    print("API Key not found!")
    return jsonify({"status": "error", "message": "API Key not found"}), 500

# Log in to Hopsworks using the API key
project = hopsworks.login(api_key_value=api_key)
fs = project.get_feature_store()

result = inference(user_input, project, fs)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from inference_pipeline import inference
#       2 import hopsworks
#       3 from flask import jsonify
#
# File c:\Users\celin_e3kjw6h\OneDrive\Bureau\KTH\ID2223 Scalable Machine Learning and Deep Learning\project\fake_news_bsky_detector\inference_pipeline.py:3
#       1 import os
# ----> 3 import hopsworks
#       4 import joblib
#       5 import pandas as pd
#
# File c:\Users\celin_e3kjw6h\miniconda3\envs\fake_news\lib\site-packages\hopsworks\__init__.py:27
#      24 from pathlib import Path
#      25 from typing import Literal, Union
# ---> 27 from hopsworks import client, constants, project, version
#      28 from hopsworks.client.exceptions import (
#      29     HopsworksSSLClientError,
#      30     ProjectException,
#      31     RestAPIError,
#      32 )
# ...
